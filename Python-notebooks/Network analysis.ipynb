# %%
import pandas as pd
import numpy as np

# %%
species = "Bacillus anthracis"

# %%
df_all = pd.read_csv("/Users/thesis/Desktop/Google Drive/thesis-lorenz/Work in progress.../Cytoscape/" + species + " all nodes.csv", usecols = [8,1,2,3,4,5,6,9,13,14,18])
df_cloud = pd.read_csv("/Users/thesis/Desktop/Google Drive/thesis-lorenz/Work in progress.../Cytoscape/" + species + " cloud nodes.csv")

# %%
df_all=df_all[["name","AverageShortestPathLength","BetweennessCentrality","ClosenessCentrality","ClusteringCoefficient","Degree","Eccentricity","NeighborhoodConnectivity","Radiality","selected","TopologicalCoefficient"]]
df_cloud = df_cloud[["name","AverageShortestPathLength","BetweennessCentrality","ClosenessCentrality","ClusteringCoefficient","Degree","Eccentricity","NeighborhoodConnectivity","Radiality","selected","TopologicalCoefficient"]]

# %%
df_cloud.sort_values("BetweennessCentrality", ascending = False)
# Out:
#             name  AverageShortestPathLength  BetweennessCentrality  \
# 454       Q81SN0                   3.895161               0.192378
# 262       P19838                   3.928763               0.178831
# 201       Q81VT8                   4.301075               0.126342
# 671       Q9NY15                   4.300627               0.091998
# 504       Q81KT8                   4.469534               0.087446
# 1236  A0A1A9IJH2                   4.076165               0.079466
# 58    A0A1V4BGP0                   4.076165               0.079466
# 303       P17931                   4.282706               0.068675
# 285       Q81YE8                   4.383513               0.064864
# 351       O00165                   4.334677               0.061721
# 472       P61769                   4.445789               0.055649
# 228       Q6KNA9                   4.329749               0.053198
# 159       Q81Z98                   4.329749               0.050886
# ...

# %%
sel = df_cloud.selected == True

# %%
df_cloud[sel]
# Out:
#             name  AverageShortestPathLength  BetweennessCentrality  \
# 0         Q5NES9                   5.674766               0.015076
# 1         P04233                   4.984112               0.193545
# 6         Q5NHE7                   6.822430               0.006286
# 7         Q96QZ7                   5.858879               0.007803
# 8         Q5NEC0                   4.869159               0.274758
# 9         Q5NGV3                   7.469159               0.035084
# 10        P27448                   8.458879               0.009311
# 11        Q5NF74                   6.519626               0.065652
# 12        P27816                   7.518692               0.000000
# 13        Q5NHK6                   9.450467               0.007456
# 15        Q5NIJ3                   6.545794               0.031341
# 16        O60318                   6.350467               0.010931
# 19        Q5NF50                   6.669159               0.059008
# ...

# %%
df_all
# Out:
#             name  AverageShortestPathLength  BetweennessCentrality  \
# 0         P40136                   1.000000           1.000000e+00
# 1         P62158                   1.666667           0.000000e+00
# 2         P13423                   4.825269           2.240085e-02
# 3         P58335                   5.824821           0.000000e+00
# 4         Q9H6X2                   5.824821           0.000000e+00
# 5         P15917                   7.037634           1.791710e-03
# 6         P46734                   8.037186           0.000000e+00
# 7         P61923                   8.037186           0.000000e+00
# 8         P53618                   6.039875           3.157670e-03
# 9         Q81P26                   6.217742           1.980290e-03
# 10        O14595                   5.831093           2.065410e-03
# 11        Q81TS3                   5.499104           3.039400e-04
# 12        Q2NL98                   4.744176           5.444290e-03
# ...
