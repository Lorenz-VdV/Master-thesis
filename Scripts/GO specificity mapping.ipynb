# %%
import pandas as pd
import numpy as np
import os
import xlwt
import re

# %%
GO = open("/Users/thesis/Desktop/Google Drive/thesis-lorenz/Work in progress.../Databases/GO/go-basic.obo", 'r')

# %%
BP =[]
MF = []
CC = []

# %%
for line in GO:
    x = line.split()
    if len(x) !=0 and x[0] == 'namespace:':
        if x[0] =='biological_process':
            BP.append()
# Out:
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'molecular_function']
# ['namespace:', 'cellular_component']
# ['namespace:', 'molecular_function']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'molecular_function']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'biological_process']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'biological_process']
# ['namespace:', 'molecular_function']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'molecular_function']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'biological_process']
# ['namespace:', 'molecular_function']
# ['namespace:', 'biological_process']
# ['namespace:', 'molecular_function']
# ['namespace:', 'biological_process']
# ['namespace:', 'molecular_function']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'molecular_function']
# ['namespace:', 'biological_process']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'biological_process']
# ['namespace:', 'cellular_component']
# ['namespace:', 'biological_process']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'molecular_function']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'molecular_function']
# ['namespace:', 'biological_process']
# ['namespace:', 'cellular_component']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'biological_process']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'cellular_component']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'cellular_component']
# ['namespace:', 'biological_process']
# ['namespace:', 'molecular_function']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'cellular_component']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'molecular_function']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'molecular_function']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'molecular_function']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'biological_process']
# ['namespace:', 'molecular_function']
# ['namespace:', 'cellular_component']
# ['namespace:', 'molecular_function']
# ['namespace:', 'biological_process']
# ['namespace:', 'molecular_function']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'biological_process']
# ['namespace:', 'molecular_function']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'molecular_function']
# ['namespace:', 'cellular_component']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'cellular_component']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'biological_process']
# ['namespace:', 'cellular_component']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'molecular_function']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'molecular_function']
# ['namespace:', 'biological_process']
# ['namespace:', 'molecular_function']
# ['namespace:', 'biological_process']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'biological_process']
# ['namespace:', 'molecular_function']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'molecular_function']
# ['namespace:', 'cellular_component']
# ['namespace:', 'molecular_function']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'molecular_function']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'cellular_component']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'cellular_component']
# ['namespace:', 'biological_process']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'biological_process']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'molecular_function']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'molecular_function']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'molecular_function']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'cellular_component']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'biological_process']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'biological_process']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'biological_process']
# ['namespace:', 'molecular_function']
# ['namespace:', 'biological_process']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'cellular_component']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'cellular_component']
# ['namespace:', 'molecular_function']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'molecular_function']
# ['namespace:', 'biological_process']
# ['namespace:', 'cellular_component']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'molecular_function']
# ['namespace:', 'biological_process']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'biological_process']
# ['namespace:', 'molecular_function']
# ['namespace:', 'biological_process']
# ['namespace:', 'molecular_function']
# ['namespace:', 'cellular_component']
# ['namespace:', 'biological_process']
# ['namespace:', 'cellular_component']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'molecular_function']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'cellular_component']
# ['namespace:', 'molecular_function']
# ['namespace:', 'cellular_component']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'molecular_function']
# ['namespace:', 'biological_process']
# ['namespace:', 'molecular_function']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'molecular_function']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'molecular_function']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'biological_process']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'molecular_function']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'cellular_component']
# ['namespace:', 'molecular_function']
# ['namespace:', 'biological_process']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'molecular_function']
# ['namespace:', 'biological_process']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'molecular_function']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'molecular_function']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'cellular_component']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'cellular_component']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'molecular_function']
# ['namespace:', 'biological_process']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'cellular_component']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'molecular_function']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'cellular_component']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ...
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'molecular_function']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'molecular_function']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'molecular_function']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'biological_process']
# ['namespace:', 'external']
# ['namespace:', 'external']
# ['namespace:', 'external']
# ['namespace:', 'external']
# ['namespace:', 'external']
