# %%
import re
import numpy as np
import pandas as pd
import xlwt
import os
import ete3
ncbi = ete3.NCBITaxa()
#ncbi.update_taxonomy_database()

# %% [markdown]
# Choose species

# %%
species ="Francisella tularensis"

# %% [markdown]
# Read in exported data files

# %%
HPIDB = pd.read_table("/Users/thesis/Desktop/Google drive/thesis-lorenz/Work in progress.../Databases/HPIDB2.0/Mitabs/" + species + "/" + species + ".txt", names=["Protein_A","Protein_B","Alt_A","Alt_B","Alias_A","Alias_B","D_method","PubmedID","Taxid_A","Taxid_B","Int_type","Source_DB","Conf_score"], usecols=[0,1,2,3,4,5,6,8,9,10,11,12,14], header=0)
IntAct = pd.read_table("/Users/thesis/Desktop/Google drive/thesis-lorenz/Work in progress.../Databases/IntAct/" + species, names=["Protein_A","Protein_B","Alt_A","Alt_B","Alias_A","Alias_B","D_method","PubmedID","Taxid_A","Taxid_B","Int_type","Source_DB","Conf_score"], usecols=[0,1,2,3,4,5,6,8,9,10,11,12,14], header=0)
PHISTO = pd.read_excel("/Users/thesis/Desktop/Google drive/thesis-lorenz/Work in progress.../Databases/PHISTO/" + species + ".xls", names= ["Taxid_A", "Protein_A", "Protein_B", "D_method","PubmedID"], usecols=[1,2,4,6,7])
print(HPIDB.Source_DB.unique())
print (len(HPIDB), len(IntAct),len(PHISTO))
# Out:
# ['psi-mi:MI:0469(IntAct)']
# 1371 1358 1331

# %% [markdown]
# IntAct and HPIDB sets are basically the same apart from their taxid columns, thus we'll clean up the taxid column of IntAct, merge the two and then clean up the rest
#
# It should also be noted that the taxid cleaning up has one step that needs to 'supervised' because sometimes the procedures creates NaN values which need to be checked manually.

# %%
r = IntAct.Taxid_A
r = r.str.lower()
r = r.str.extract(r'(?:taxid:)([0-9]*)',expand = False)
IntAct.Taxid_A = r

r = IntAct.Taxid_B
r = r.str.lower()
r = r.str.extract(r'(?:taxid:)([0-9]*)',expand = False)
IntAct.Taxid_B = r

# %%
df=pd.concat([HPIDB,IntAct])
df=df.reset_index(drop=True)

# %%
len(df)
# Out:
# 2729

# %%
taxids= list(pd.unique(list(df.Taxid_A.unique())+list(pd.unique(list(df.Taxid_B.unique())))))
parent= ncbi.get_name_translator([species])
taxid_list=[]
for taxid in taxids:
    lineage = ncbi.get_lineage(taxid)
    
    if parent.get(species)[0] in lineage:
        taxid_list.append(taxid)
taxid_list.append('9606')

# %%
print(ncbi.get_taxid_translator(taxid_list))
sel1 = df.Taxid_A.apply(lambda x: str(x) in taxid_list)
sel2 = df.Taxid_B.apply(lambda x: str(x) in taxid_list)
df = df.loc[sel1 & sel2,:]
# Out:
# {9606: 'Homo sapiens', 119856: 'Francisella tularensis subsp. tularensis', 177416: 'Francisella tularensis subsp. tularensis SCHU S4'}

# %%
len(df)
# Out:
# 2729

# %%
for name in ["D_method","Int_type","Source_DB"]:
    r = df[name]
    r = r.str.extract((r'(?:psi-mi:"?MI:[0-9]*"?[(])([^)]*)(?:[)])') ,expand = False)
    df[name] = r


for name in ["Protein_A","Protein_B"]:
    r = df[name]
    r = r.str.extract(r'(?:uniprotkb:)([a-zA-Z0-9]*)', expand=False)
    df[name] = r
    

r = df.PubmedID
r = r.str.extract(r'(?:[^p]*)(?:pubmed:)([0-9]*)(?:.*)',expand=False)
df.PubmedID = r

r = df.Conf_score
r = r.str.extract(r'(?:intact-miscore:)([0-9.]*)', expand=False)
df.Conf_score = r

# %% [markdown]
# Some entries don't have uniprot ID
# We'll search the alt ID column for a uniprot ID
# However, in the particular case of B anthracis, there are no Alt Ids available => entries 714-761 in intact file for protein A
# Protein B is spread across the dataset.
#
# Upon further inspection most of these entries trace back do deleted entries in the uniprotKB database.
#     Some of these due to deletion. We don't know (yet) if this deletion is due to being wrong or upon request of original submitters
#         Others due to redundancy. Trace back to the non redundant entry might be done by downloading the sequence and finding it in the uniprot database? example entry index 56 of intact file
#         EBI-2810906 => a0a1v4b700_bacan =>
# The other entries aren't even traceable

# %%
sel1 = df.Protein_A.isnull()
subset1 = df.loc[sel1,"Alt_A"]
sel2 = df.Protein_B.isnull()
subset2 = df.loc[sel2,"Alt_B"]

#Maar 1 ID kolom overhouden of beter om gwn alt IDs en aliases in de kolommen te houden 
#en dan in de andere scripts dan rekening te houden da ge daar ook kunt gaan zoeken
# Out:
#      Protein_A Protein_B                                              Alt_A  \
# 0       P13598    Q8G8T7                intact:EBI-2806056|uniprotkb:Q14600
# 1       P19838    Q8G8T7  intact:EBI-300010|uniprotkb:A8K5Y5|uniprotkb:B...
# 2       Q9BV68    Q8G8T7                 intact:EBI-357322|uniprotkb:Q9NWX1
# 3          NaN    Q4VP87                                                  -
# 4          NaN    Q79RC1                                                  -
# 5       O60763    Q8G8T7  intact:EBI-356164|uniprotkb:Q6PK63|uniprotkb:Q...
# 6       P01877    Q4VP87                                 intact:EBI-1044357
# 7       P01877    Q8G8T7                                 intact:EBI-1044357
# 8       P13693    Q4VP87  intact:EBI-1783169|intact:EBI-1058458|uniprotk...
# 9       P30480    Q4VP87                intact:EBI-1054175|uniprotkb:P79555
# 10      P31321    Q79RC1                intact:EBI-2805516|uniprotkb:Q8N422
# 11      P52566    Q8G8T7                intact:EBI-2806617|uniprotkb:B5BU79
# 12      P62314    Q8G8T7  intact:EBI-372177|uniprotkb:P13641|uniprotkb:B...
# 13      P69905    Q8G8T7  intact:EBI-714680|uniprotkb:Q1HDT5|uniprotkb:Q...
# 14      Q10587    Q79RC1  intact:EBI-2796967|uniprotkb:Q8IU94|uniprotkb:...
# 15      Q14590    Q4VP87  intact:EBI-2796853|uniprotkb:O14898|uniprotkb:...
# 16      Q7Z3K3    Q8G8T7  intact:EBI-1389308|intact:EBI-2560449|uniprotk...
# 17      Q86VB7    Q4VP87  intact:EBI-2808455|uniprotkb:Q07901|uniprotkb:...
# 18      Q86Y74    Q4VP87                                 intact:EBI-2807597
# 19      Q8NHJ6    Q4VP87  intact:EBI-2805248|uniprotkb:A8MVL8|uniprotkb:...
# 20      Q8NHL6    Q4VP87  intact:EBI-2805262|uniprotkb:Q8NHK0|uniprotkb:...
# 21      Q96GE9    Q4VP87  intact:EBI-2799162|uniprotkb:Q9NT74|uniprotkb:...
# 15    two hybrid pooling approach  20711500    9606  119856
# 16    two hybrid pooling approach  20711500    9606  119856
# 17    two hybrid pooling approach  20711500    9606  119856
# 18    two hybrid pooling approach  20711500    9606  119856
# 19    two hybrid pooling approach  20711500    9606  119856
# 20    two hybrid pooling approach  20711500    9606  119856
# 21    two hybrid pooling approach  20711500    9606  119856
# 22    two hybrid pooling approach  20711500    9606  119856
# 23    two hybrid pooling approach  20711500    9606  119856
# 24    two hybrid pooling approach  20711500    9606  119856
# 25    two hybrid pooling approach  20711500    9606  177416
# 26    two hybrid pooling approach  20711500    9606  177416
# 27    two hybrid pooling approach  20711500    9606  177416
# 28    two hybrid pooling approach  20711500    9606  177416
# 29    two hybrid pooling approach  20711500    9606  177416
# ...                           ...       ...     ...     ...
# 2699  two hybrid pooling approach  20711500  177416    9606
# 2700  two hybrid pooling approach  20711500    9606  177416
# 2701  two hybrid pooling approach  20711500    9606  177416
# 2702  two hybrid pooling approach  20711500    9606  177416
# 2703  two hybrid pooling approach  20711500    9606  177416
# 2704  two hybrid pooling approach  20711500  177416    9606
# 2705  two hybrid pooling approach  20711500  177416    9606
# 2706  two hybrid pooling approach  20711500  177416    9606
# 2707  two hybrid pooling approach  20711500    9606  177416
# 2708  two hybrid pooling approach  20711500    9606  177416
# 2709  two hybrid pooling approach  20711500    9606  177416
# 2710  two hybrid pooling approach  20711500    9606  177416
# 2711  two hybrid pooling approach  20711500  177416    9606
# 2712  two hybrid pooling approach  20711500    9606  177416
# 2713  two hybrid pooling approach  20711500  177416    9606
# 2714  two hybrid pooling approach  20711500    9606  177416
# 2715  two hybrid pooling approach  20711500    9606  177416
# 2716  two hybrid pooling approach  20711500    9606  177416
# 2717  two hybrid pooling approach  20711500    9606  177416
# 2718  two hybrid pooling approach  20711500    9606  177416
# 2719  two hybrid pooling approach  20711500    9606  177416
# 2720  two hybrid pooling approach  20711500  177416    9606
# 2721  two hybrid pooling approach  20711500    9606  177416
# 2722  two hybrid pooling approach  20711500  177416    9606
# 2723  two hybrid pooling approach  20711500    9606  177416
# 2724  two hybrid pooling approach  20711500    9606  177416
# 2725  two hybrid pooling approach  20711500    9606  177416
# 2726  two hybrid pooling approach  20711500  177416    9606
# 2727  two hybrid pooling approach  20711500  177416    9606
# 2728  two hybrid pooling approach  20711500    9606  177416
#
#                   Int_type Source_DB Conf_score
# 0     physical association    IntAct       0.37
# 1     physical association    IntAct       0.37
# 2     physical association    IntAct       0.37
# 3     physical association    IntAct       0.37
# 4     physical association    IntAct       0.37
# 5     physical association    IntAct       0.37
# 6     physical association    IntAct       0.37
# 7     physical association    IntAct       0.37
# 8     physical association    IntAct       0.37
# 9     physical association    IntAct       0.37
# 10    physical association    IntAct       0.37
# 11    physical association    IntAct       0.37
# 12    physical association    IntAct       0.37
# 13    physical association    IntAct       0.37
# 14    physical association    IntAct       0.37
# 15    physical association    IntAct       0.37
# 16    physical association    IntAct       0.37
# 17    physical association    IntAct       0.37
# 18    physical association    IntAct       0.37
# 19    physical association    IntAct       0.37
# 20    physical association    IntAct       0.37
# 21    physical association    IntAct       0.37
# 22    physical association    IntAct       0.37
# 23    physical association    IntAct       0.37
# 24    physical association    IntAct       0.37
# 25    physical association    IntAct       0.37
# 26    physical association    IntAct       0.37
# 27    physical association    IntAct       0.37
# 28    physical association    IntAct       0.37
# 29    physical association    IntAct       0.37
# ...                    ...       ...        ...
# 2699  physical association    IntAct       0.37
# 2700  physical association    IntAct       0.37
# 2701  physical association    IntAct       0.37
# 2702  physical association    IntAct       0.37
# 2703  physical association    IntAct       0.37
# 2704  physical association    IntAct       0.37
# 2705  physical association    IntAct       0.37
# 2706  physical association    IntAct       0.37
# 2707  physical association    IntAct       0.37
# 2708  physical association    IntAct       0.37
# 2709  physical association    IntAct       0.37
# 2710  physical association    IntAct       0.37
# 2711  physical association    IntAct       0.37
# 2712  physical association    IntAct       0.37
# 2713  physical association    IntAct       0.37
# 2714  physical association    IntAct       0.37
# 2715  physical association    IntAct       0.37
# 2716  physical association    IntAct       0.37
# 2717  physical association    IntAct       0.37
# 2718  physical association    IntAct       0.37
# 2719  physical association    IntAct       0.37
# 2720  physical association    IntAct       0.37
# 2721  physical association    IntAct       0.37
# 2722  physical association    IntAct       0.37
# 2723  physical association    IntAct       0.37
# 2724  physical association    IntAct       0.37
# 2725  physical association    IntAct       0.37
# 2726  physical association    IntAct       0.37
# 2727  physical association    IntAct       0.37
# 2728  physical association    IntAct       0.37
#
# [2729 rows x 13 columns]

# %%
sel1 = df.Protein_A.isnull()
sel2 = df.Protein_B.isnull()
df = df.loc[~sel1 & ~sel2,:]
df = df.reset_index(drop=True)

# %%
len(df)
# Out:
# 2637

# %%
df = df.drop(["Alt_A","Alt_B"],axis=1)

# %% [markdown]
# Sort columns so pathogen is 'A' and human is 'B'

# %%
df.Taxid_A= df.Taxid_A.apply(lambda x: str(x))
df.Taxid_B = df.Taxid_B.apply(lambda x: str(x))
for i in range(len(df)):
    if df.loc[i,"Taxid_B"] != '9606':
        A = df.loc[i,"Taxid_A"]
        B = df.loc[i,"Taxid_B"]
        C = df.loc[i,"Protein_A"]
        D = df.loc[i,"Protein_B"]
      

        df.loc[i,"Taxid_A"] = B
        df.loc[i,"Taxid_B"] = A
        df.loc[i,"Protein_A"]= D
        df.loc[i,"Protein_B"]= C

# %% [markdown]
# Filter out non-HPIs

# %%
sel = df.Taxid_B == '9606'

# %%
df = df.loc[sel,:]
print(len(df))
# Out:
# 2637

# %% [markdown]
# Make identifier df

# %%
ID_all =[]
for i in range (0,len(df)):
    ID_list=[]
    ID_list.append (df.iloc[i,0])
    ID_list.append (df.iloc[i,1])
    ID_list.append (df.iloc[i,3])
    ID_list.append (df.iloc[i,2])
    ID_list.sort()
    ID_all.append(
        ID_list[0]
        +ID_list[1] 
        + str(ID_list[2])
        +ID_list[3]
    )
df=df.assign(ID=ID_all)

# %%
print(len(df.ID.unique()))
df.PubmedID.unique()
# Out:
# 1330
# array(['20711500'], dtype=object)

# %% [markdown]
# Make identifier PHISTO and make Taxid_B column

# %%
ID_all =[]
for i in range (0,len(PHISTO)):
    ID_list=[]
    ID_list.append (PHISTO.iloc[i,1])
    ID_list.append (PHISTO.iloc[i,2])
    ID_list.append (PHISTO.iloc[i,3])
    ID_list.append (str(PHISTO.iloc[i,4]))
    ID_list.sort()
    ID_all.append(
        ID_list[0]
        +ID_list[1] 
        + ID_list[2]
        + ID_list[3]
    )
PHISTO=PHISTO.assign(ID=ID_all)

PHISTO["Taxid_B"]="9606"
PHISTO["Source_DB"]="PHISTO"

# %%
print(len(PHISTO.ID.unique()))
print(len(PHISTO))
# Out:
# 1331
# 1331

# %% [markdown]
# merge df and PHISTO

# %%
df = pd.concat([df,PHISTO])
len(df)
# Out:
# 3968

# %% [markdown]
# Remove redundancy

# %%
df = df.sort_values(by = "Conf_score", ascending = False)
df = df.drop_duplicates("ID")
print(len(df))
# Out:
# 1335

# %% [markdown]
# Count how many times an interaction has been found with different methods, different types of interactions, different publications,...

# %%
count=df.groupby(["Source_DB"]).count()
count
# Out:
#            Conf_score  D_method    ID  Int_type  Protein_A  Protein_B  \
# Source_DB
# IntAct           1330      1330  1330      1330       1330       1330
# PHISTO              0         5     5         0          5          5
#
#            PubmedID  Taxid_A  Taxid_B
# Source_DB
# IntAct         1330     1330     1330
# PHISTO            5        5        5

# %%
df.groupby("PubmedID").size()
# Out:
# PubmedID
# 20711500       5
# 20711500    1330
# dtype: int64

# %%
df = df.reset_index()
df = df[["Taxid_A","Taxid_B","Protein_A","Protein_B","Int_type","D_method","PubmedID","Source_DB","Conf_score","ID"]]

# %%
df.to_csv("/Users/thesis/Desktop/Python scripts/Test outputs/" + species, sep ="\t")

# %%
df
# Out:
#      Taxid_A Taxid_B Protein_A   Protein_B              Int_type  \
# 0     119856    9606    Q8G8T7      P13598  physical association
# 1     177416    9606    Q5NID9      Q15650  physical association
# 2     177416    9606    Q5NF74      Q96A61  physical association
# 3     177416    9606    Q5NGC7      Q92547  physical association
# 4     177416    9606    Q5NIP6      O14773  physical association
# 5     177416    9606    Q5NEV2      O94842  physical association
# 6     177416    9606    Q5NES5      Q8IYM9  physical association
# 7     177416    9606    Q5NEX4      Q8NDV7  physical association
# 8     177416    9606    Q5NIP6      Q8NDV7  physical association
# 9     177416    9606    Q5NHD1      O94826  physical association
# 10    177416    9606    Q5NHH2      Q96GC9  physical association
# 11    177416    9606    Q5NEY0      Q06643  physical association
# 12    177416    9606    Q5NF50      Q92956  physical association
# 13    177416    9606    Q5NGT9      Q96BY9  physical association
# 14    177416    9606    Q5NI93      Q15025  physical association
# 15    177416    9606    Q5NH45      Q9HC24  physical association
# 16    177416    9606    Q5NHH2      Q15363  physical association
# 17    177416    9606    Q5NH29      Q9ULS5  physical association
# 18    177416    9606    Q5NIP6      P57088  physical association
# 19    177416    9606    Q5NID2      Q8IYM9  physical association
# 20    177416    9606    Q5NFM0      Q14258  physical association
# 21    177416    9606    Q5NHD1      Q9H5I1  physical association
# 22    177416    9606    Q5NF08      Q8IYM9  physical association
# 23    177416    9606    Q5NGF9      Q6PKC3  physical association
# 24    177416    9606    Q5NHX0      O43396  physical association
# 25    177416    9606    Q5NFP9      Q9BS26  physical association
# 26    177416    9606    Q5NEC0      P63313  physical association
# 27    177416    9606    Q5NHN4      P26651  physical association
# 28    177416    9606    Q5NFN2      O14907  physical association
# 29    177416    9606    Q5NE82      P53804  physical association
# ...      ...     ...       ...         ...                   ...
# 1305  177416    9606    Q5NHR0      Q9NR56  physical association
# 1306  177416    9606    Q5NHK6      P27448  physical association
# 1307  177416    9606    Q5NF74      P27816  physical association
# 1308  119856    9606    Q8G8T7      P19838  physical association
# 1309  119856    9606    Q8G8T7      Q9Y6C2  physical association
# 1310  119856    9606    Q79RC1      Q9NZ32  physical association
# 1311  119856    9606    Q79RC4      Q96GX9  physical association
# 1312  119856    9606    Q4VP87      Q96GE9  physical association
# 1313  119856    9606    Q8G8T7      P52566  physical association
# 1314  119856    9606    Q8G8T7      Q9BV68  physical association
# 1315  119856    9606    Q8G8T7      O60763  physical association
# 1316  119856    9606    Q4VP87      P01877  physical association
# 1317  119856    9606    Q8G8T7      P01877  physical association
# 1318  119856    9606    Q4VP87      P13693  physical association
# 1319  119856    9606    Q4VP87      P30480  physical association
# 1320  119856    9606    Q79RC1      P31321  physical association
# 1321  119856    9606    Q8G8T7      P62314  physical association
# 1322  119856    9606    Q4VP87      Q8NHL6  physical association
# 1323  119856    9606    Q8G8T7      P69905  physical association
# 1324  119856    9606    Q79RC1      Q10587  physical association
# 1325  119856    9606    Q4VP87      Q14590  physical association
# 1326  119856    9606    Q8G8T7      Q7Z3K3  physical association
# 1327  119856    9606    Q4VP87      Q86VB7  physical association
# 1328  119856    9606    Q4VP87      Q86Y74  physical association
# 1329  119856    9606    Q4VP87      Q8NHJ6  physical association
# 1330  177416    9606    Q5NIF9  A0A1L1M261                   NaN
# 1331  177416    9606    Q5NEC0  A0A1L1M261                   NaN
# 1332  177416    9606    Q5NH91  A0A1L1M261                   NaN
# 1333  177416    9606    Q5NGC3  A0A1L1M261                   NaN
# 1334  119856    9606    Q8G8T7      D1MGQ2                   NaN
#
#                          D_method  PubmedID Source_DB Conf_score  \
# 0     two hybrid pooling approach  20711500    IntAct       0.37
# 1     two hybrid pooling approach  20711500    IntAct       0.37
# 2     two hybrid pooling approach  20711500    IntAct       0.37
# 3     two hybrid pooling approach  20711500    IntAct       0.37
# 4     two hybrid pooling approach  20711500    IntAct       0.37
# 5     two hybrid pooling approach  20711500    IntAct       0.37
# 6     two hybrid pooling approach  20711500    IntAct       0.37
# 7     two hybrid pooling approach  20711500    IntAct       0.37
# 8     two hybrid pooling approach  20711500    IntAct       0.37
# 9     two hybrid pooling approach  20711500    IntAct       0.37
# 10    two hybrid pooling approach  20711500    IntAct       0.37
# 11    two hybrid pooling approach  20711500    IntAct       0.37
# 12    two hybrid pooling approach  20711500    IntAct       0.37
# 13    two hybrid pooling approach  20711500    IntAct       0.37
# 14    two hybrid pooling approach  20711500    IntAct       0.37
# 15    two hybrid pooling approach  20711500    IntAct       0.37
# 16    two hybrid pooling approach  20711500    IntAct       0.37
# 17    two hybrid pooling approach  20711500    IntAct       0.37
# 18    two hybrid pooling approach  20711500    IntAct       0.37
# 19    two hybrid pooling approach  20711500    IntAct       0.37
# 20    two hybrid pooling approach  20711500    IntAct       0.37
# 21    two hybrid pooling approach  20711500    IntAct       0.37
# 22    two hybrid pooling approach  20711500    IntAct       0.37
# 23    two hybrid pooling approach  20711500    IntAct       0.37
# 24    two hybrid pooling approach  20711500    IntAct       0.37
# 25    two hybrid pooling approach  20711500    IntAct       0.37
# 26    two hybrid pooling approach  20711500    IntAct       0.37
# 27    two hybrid pooling approach  20711500    IntAct       0.37
# 28    two hybrid pooling approach  20711500    IntAct       0.37
# 29    two hybrid pooling approach  20711500    IntAct       0.37
# ...                           ...       ...       ...        ...
# 1305  two hybrid pooling approach  20711500    IntAct       0.37
# 1306  two hybrid pooling approach  20711500    IntAct       0.37
# 1307  two hybrid pooling approach  20711500    IntAct       0.37
# 1308  two hybrid pooling approach  20711500    IntAct       0.37
# 1309  two hybrid pooling approach  20711500    IntAct       0.37
# 1310  two hybrid pooling approach  20711500    IntAct       0.37
# 1311  two hybrid pooling approach  20711500    IntAct       0.37
# 1312  two hybrid pooling approach  20711500    IntAct       0.37
# 1313  two hybrid pooling approach  20711500    IntAct       0.37
# 1314  two hybrid pooling approach  20711500    IntAct       0.37
# 1315  two hybrid pooling approach  20711500    IntAct       0.37
# 1316  two hybrid pooling approach  20711500    IntAct       0.37
# 1317  two hybrid pooling approach  20711500    IntAct       0.37
# 1318  two hybrid pooling approach  20711500    IntAct       0.37
# 1319  two hybrid pooling approach  20711500    IntAct       0.37
# 1320  two hybrid pooling approach  20711500    IntAct       0.37
# 1321  two hybrid pooling approach  20711500    IntAct       0.37
# 1322  two hybrid pooling approach  20711500    IntAct       0.37
# 1323  two hybrid pooling approach  20711500    IntAct       0.37
# 1324  two hybrid pooling approach  20711500    IntAct       0.37
# 1325  two hybrid pooling approach  20711500    IntAct       0.37
# 1326  two hybrid pooling approach  20711500    IntAct       0.37
# 1327  two hybrid pooling approach  20711500    IntAct       0.37
# 1328  two hybrid pooling approach  20711500    IntAct       0.37
# 1329  two hybrid pooling approach  20711500    IntAct       0.37
# 1330  two hybrid pooling approach  20711500    PHISTO        NaN
# 1331  two hybrid pooling approach  20711500    PHISTO        NaN
# 1332  two hybrid pooling approach  20711500    PHISTO        NaN
# 1333  two hybrid pooling approach  20711500    PHISTO        NaN
# 1334  two hybrid pooling approach  20711500    PHISTO        NaN
#
#                                                      ID
# 0       20711500P13598Q8G8T7two hybrid pooling approach
# 1       20711500Q15650Q5NID9two hybrid pooling approach
# 2       20711500Q5NF74Q96A61two hybrid pooling approach
# 3       20711500Q5NGC7Q92547two hybrid pooling approach
# 4       20711500O14773Q5NIP6two hybrid pooling approach
# 5       20711500O94842Q5NEV2two hybrid pooling approach
# 6       20711500Q5NES5Q8IYM9two hybrid pooling approach
# 7       20711500Q5NEX4Q8NDV7two hybrid pooling approach
# 8       20711500Q5NIP6Q8NDV7two hybrid pooling approach
# 9       20711500O94826Q5NHD1two hybrid pooling approach
# 10      20711500Q5NHH2Q96GC9two hybrid pooling approach
# 11      20711500Q06643Q5NEY0two hybrid pooling approach
# 12      20711500Q5NF50Q92956two hybrid pooling approach
# 13      20711500Q5NGT9Q96BY9two hybrid pooling approach
# 14      20711500Q15025Q5NI93two hybrid pooling approach
# 15      20711500Q5NH45Q9HC24two hybrid pooling approach
# 16      20711500Q15363Q5NHH2two hybrid pooling approach
# 17      20711500Q5NH29Q9ULS5two hybrid pooling approach
# 18      20711500P57088Q5NIP6two hybrid pooling approach
# 19      20711500Q5NID2Q8IYM9two hybrid pooling approach
# 20      20711500Q14258Q5NFM0two hybrid pooling approach
# 21      20711500Q5NHD1Q9H5I1two hybrid pooling approach
# 22      20711500Q5NF08Q8IYM9two hybrid pooling approach
# 23      20711500Q5NGF9Q6PKC3two hybrid pooling approach
# 24      20711500O43396Q5NHX0two hybrid pooling approach
# 25      20711500Q5NFP9Q9BS26two hybrid pooling approach
# 26      20711500P63313Q5NEC0two hybrid pooling approach
# 27      20711500P26651Q5NHN4two hybrid pooling approach
# 28      20711500O14907Q5NFN2two hybrid pooling approach
# 29      20711500P53804Q5NE82two hybrid pooling approach
# ...                                                 ...
# 1305    20711500Q5NHR0Q9NR56two hybrid pooling approach
# 1306    20711500P27448Q5NHK6two hybrid pooling approach
# 1307    20711500P27816Q5NF74two hybrid pooling approach
# 1308    20711500P19838Q8G8T7two hybrid pooling approach
# 1309    20711500Q8G8T7Q9Y6C2two hybrid pooling approach
# 1310    20711500Q79RC1Q9NZ32two hybrid pooling approach
# 1311    20711500Q79RC4Q96GX9two hybrid pooling approach
# 1312    20711500Q4VP87Q96GE9two hybrid pooling approach
# 1313    20711500P52566Q8G8T7two hybrid pooling approach
# 1314    20711500Q8G8T7Q9BV68two hybrid pooling approach
# 1315    20711500O60763Q8G8T7two hybrid pooling approach
# 1316    20711500P01877Q4VP87two hybrid pooling approach
# 1317    20711500P01877Q8G8T7two hybrid pooling approach
# 1318    20711500P13693Q4VP87two hybrid pooling approach
# 1319    20711500P30480Q4VP87two hybrid pooling approach
# 1320    20711500P31321Q79RC1two hybrid pooling approach
# 1321    20711500P62314Q8G8T7two hybrid pooling approach
# 1322    20711500Q4VP87Q8NHL6two hybrid pooling approach
# 1323    20711500P69905Q8G8T7two hybrid pooling approach
# 1324    20711500Q10587Q79RC1two hybrid pooling approach
# 1325    20711500Q14590Q4VP87two hybrid pooling approach
# 1326    20711500Q7Z3K3Q8G8T7two hybrid pooling approach
# 1327    20711500Q4VP87Q86VB7two hybrid pooling approach
# 1328    20711500Q4VP87Q86Y74two hybrid pooling approach
# 1329    20711500Q4VP87Q8NHJ6two hybrid pooling approach
# 1330  20711500A0A1L1M261Q5NIF9two hybrid pooling app...
# 1331  20711500A0A1L1M261Q5NEC0two hybrid pooling app...
# 1332  20711500A0A1L1M261Q5NH91two hybrid pooling app...
# 1333  20711500A0A1L1M261Q5NGC3two hybrid pooling app...
# 1334    20711500D1MGQ2Q8G8T7two hybrid pooling approach
#
# [1335 rows x 10 columns]
