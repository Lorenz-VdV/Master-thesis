# %%
import re
import numpy as np
import pandas as pd
import xlwt
import os
import ete3
ncbi = ete3.NCBITaxa()
import requests
import time
#ncbi.update_taxonomy_database()

# %%
BASE = 'http://www.uniprot.org'
KB_ENDPOINT = '/uniprot/'
TOOL_ENDPOINT = '/uploadlists/'

# %% [markdown]
# Choose species

# %%
species = input('Enter species')
# Out:
# Enter speciesYersinia pestis

# %% [markdown]
# Read in exported data files

# %%
HPIDB = pd.read_table("/Users/thesis/Desktop/Google drive/thesis-lorenz/Work in progress.../Databases/HPIDB2.0/Mitabs/" + species + "/" + species + ".txt", names=["protein_a","protein_b","alias_a","alias_b","d_method","pubmedid","taxid_a","taxid_b","int_type","source_db","conf_score"], usecols=[0,1,4,5,6,8,9,10,11,12,14], header=0)
IntAct = pd.read_table("/Users/thesis/Desktop/Google drive/thesis-lorenz/Work in progress.../Databases/IntAct/" + species, names=["protein_a","protein_b","alias_a","alias_b","d_method","pubmedid","taxid_a","taxid_b","int_type","source_db","conf_score"], usecols=[0,1,4,5,6,8,9,10,11,12,14], header=0)
PHISTO = pd.read_excel("/Users/thesis/Desktop/Google drive/thesis-lorenz/Work in progress.../Databases/PHISTO/" + species + ".xls", names= ["taxid_a", "protein_a", "protein_b", "d_method","pubmedid"], usecols=[1,2,4,6,7])
print(HPIDB.source_db.unique())
print (len(HPIDB), len(IntAct),len(PHISTO))
# Out:
# ['psi-mi:MI:0471(MINT)' 'psi-mi:MI:0469(IntAct)']
# 4026 4090 4089

# %% [markdown]
# IntAct and HPIDB sets are basically the same apart from their taxid columns, thus we'll clean up the taxid column of IntAct, merge the two and then clean up the rest
#
# It should also be noted that the taxid cleaning up has one step that needs to 'supervised' because sometimes the procedures creates NaN values which need to be checked manually.

# %%
r = IntAct.taxid_a
r = r.str.lower()
r = r.str.extract(r'(?:taxid:)([0-9]*)',expand = False)
IntAct.taxid_a = r

r = IntAct.taxid_b
r = r.str.lower()
r = r.str.extract(r'(?:taxid:)([0-9]*)',expand = False)
IntAct.taxid_b = r

# %%
df=pd.concat([HPIDB,IntAct])
df=df.reset_index(drop=True)

# %%
len(df)
# Out:
# 8116

# %%
taxids= list(pd.unique(list(df.taxid_a.unique())+list(pd.unique(list(df.taxid_b.unique())))))
parent= ncbi.get_name_translator([species])
taxid_list=[]
for taxid in taxids:
    lineage = ncbi.get_lineage(taxid)
    
    if parent.get(species)[0] in lineage:
        taxid_list.append(taxid)
taxid_list.append('9606')

# %%
print(ncbi.get_taxid_translator(taxid_list))
sel1 = df.taxid_a.apply(lambda x: str(x) in taxid_list)
sel2 = df.taxid_b.apply(lambda x: str(x) in taxid_list)
df = df.loc[sel1 & sel2,:]
# Out:
# {632: 'Yersinia pestis', 9606: 'Homo sapiens', 360102: 'Yersinia pestis Antiqua'}

# %%
len(df)
# Out:
# 8097

# %%
for name in ["d_method","int_type","source_db"]:
    r = df[name]
    r = r.str.extract((r'(?:psi-mi:"?MI:[0-9]*"?[(])([^)]*)(?:[)])') ,expand = False)
    df[name] = r


for name in ["protein_a","protein_b"]:
    r = df[name]
    r = r.str.extract(r'(?:uniprotkb:)([a-zA-Z0-9]*)', expand=False)
    df[name] = r
    

r = df.pubmedid
r = r.str.extract(r'(?:[^p]*)(?:pubmed:)([0-9]*)(?:.*)',expand=False)
df.pubmedid = r

r = df.conf_score
r = r.str.extract(r'(?:intact-miscore:)([0-9.]*)', expand=False)
df.conf_score = r

# %% [markdown]
# Some entries don't have uniprot ID
# We'll search the alt ID column for a uniprot ID
# However, in the particular case of B anthracis, there are no Alt Ids available => entries 714-761 in intact file for protein A
# Protein B is spread across the dataset.
#
# Upon further inspection most of these entries trace back do deleted entries in the uniprotKB database.
#     Some of these due to deletion. We don't know (yet) if this deletion is due to being wrong or upon request of original submitters
#         Others due to redundancy. Trace back to the non redundant entry might be done by downloading the sequence and finding it in the uniprot database? example entry index 56 of intact file
#         EBI-2810906 => a0a1v4b700_bacan =>
# The other entries aren't even traceable

# %%
def Find_alt_ID(ID,organism):
    if type(ID) != str:
        return 'not a string'
    time.sleep(0.5)
    payload = {'query': 'gene:' + '\"'+ ID +'\"'+ 'AND organism:' + '\"' + organism + '\"' + 'AND reviewed:yes',
           'format': 'list'}

    result2 = requests.get(BASE + KB_ENDPOINT, params=payload)

    if result2.ok:
        return(result2.text).strip()
    else:
        print('Something went wrong ', result.status_code)

# %%
sel1 = df.protein_a.isnull()
subset1 = df.loc[sel1,"alias_a"]
subset1 = subset1.str.extract(r'uniprotkb:([a-zA-Z0-9_-]*)\(gene name\)',expand=False)
subset1 = subset1.apply(lambda x : Find_alt_ID(x,'Human'))
subset1
df.loc[sel1,"protein_a"] = subset1

# %%
sel2 = df.protein_b.isnull()
subset2 = df.loc[sel2,"alias_b"]
subset2 = subset2.str.extract(r'uniprotkb:([a-zA-Z0-9_-]*)\(gene name\)',expand=False)
subset2 = subset2.apply(lambda x : Find_alt_ID(x,species))
df.loc[sel1,"protein_b"] = subset2

# %%
sel1 = df.protein_a.isnull()
sel2 = df.protein_b.isnull()
df = df.loc[~sel1 & ~sel2,:]
df = df.drop(['alias_a','alias_b'],axis=1)
df = df.reset_index(drop=True)

# %%
df
# Out:
#      protein_a protein_b                            d_method  pubmedid  \
# 0       Q9UBN7    Q7CFX2         two hybrid pooling approach  20711500
# 1       Q8WUM4    Q8ZCT2         two hybrid pooling approach  20711500
# 2       Q8WUM4    Q8ZG09         two hybrid pooling approach  20711500
# 3       Q8WUM4    Q7ARD3         two hybrid pooling approach  20711500
# 4       Q9NTJ3    Q7CFP8         two hybrid pooling approach  20711500
# 5       Q9NTJ3    Q56991         two hybrid pooling approach  20711500
# 6       P42704    Q9Z381         two hybrid pooling approach  20711500
# 7       P51572    Q8ZIL4         two hybrid pooling approach  20711500
# 8       Q86V81    Q7CJB1         two hybrid pooling approach  20711500
# 9       Q99550    Q8ZGJ1         two hybrid pooling approach  20711500
# 10      P50613    Q7CJU3         two hybrid pooling approach  20711500
# 11      O43390    Q8D068         two hybrid pooling approach  20711500
# 12      O43390    Q7CJF5         two hybrid pooling approach  20711500
# 13      Q13137    Q7CGN8         two hybrid pooling approach  20711500
# 14      O75886    Q8D015         two hybrid pooling approach  20711500
# 15      O75886    Q8D014         two hybrid pooling approach  20711500
# 16      Q9UNE7    Q7CK82         two hybrid pooling approach  20711500
# 17      Q9UNE7    Q7CL48         two hybrid pooling approach  20711500
# 18      Q9UNE7    Q7CGH6         two hybrid pooling approach  20711500
# 19      Q9UNE7    Q7CL91         two hybrid pooling approach  20711500
# 20      Q15459    Q7CL85         two hybrid pooling approach  20711500
# 21      P55265    Q7CJF5         two hybrid pooling approach  20711500
# 22      O95197    Q8ZEC9         two hybrid pooling approach  20711500
# 23      Q15025    Q8ZC49         two hybrid pooling approach  20711500
# 24      Q15025    Q7CHY3         two hybrid pooling approach  20711500
# 25      Q13422    Q9Z375         two hybrid pooling approach  20711500
# 26      P04350    Q8ZD36         two hybrid pooling approach  20711500
# 27      P04350    P58492         two hybrid pooling approach  20711500
# 28      P63244    Q8CZY2         two hybrid pooling approach  20711500
# 29      P63244    Q8D1J6         two hybrid pooling approach  20711500
# ...        ...       ...                                 ...       ...
# 7839    Q96MW5    Q8D1R1         two hybrid pooling approach  20711500
# 7840    P39059    Q8CZQ9         two hybrid pooling approach  20711500
# 7841    Q96JB2    Q8ZA88         two hybrid pooling approach  20711500
# 7842    Q96JB2    Q7CG01         two hybrid pooling approach  20711500
# 7843    Q8D177    Q14746         two hybrid pooling approach  20711500
# 7844    Q7CJX7    P39059         two hybrid pooling approach  20711500
# 7845    P23528    Q7CI41         two hybrid pooling approach  20711500
# 7846    Q7CKJ7    P23528         two hybrid pooling approach  20711500
# 7847    Q8D0R4    P23528         two hybrid pooling approach  20711500
# 7848    Q7CK47    P23528         two hybrid pooling approach  20711500
# 7849    P23528    Q8D0X3         two hybrid pooling approach  20711500
# 7850    Q99715    Q7ARB3         two hybrid pooling approach  20711500
# 7851    P23528    Q7CGU7         two hybrid pooling approach  20711500
# 7852    P23528    Q7CHX9         two hybrid pooling approach  20711500
# 7853    P58582    P23528         two hybrid pooling approach  20711500
# 7854    Q99715    Q8CZR4         two hybrid pooling approach  20711500
# 7855    P0C0L5    Q8ZAR3         two hybrid pooling approach  20711500
# 7856    P12109    Q9ZGX5         two hybrid pooling approach  20711500
# 7857    P12111    Q0WJP9         two hybrid pooling approach  20711500
# 7858    Q8ZJ73    P12109         two hybrid pooling approach  20711500
# 7859    Q7ARD3    P10643         two hybrid pooling approach  20711500
# 7860    P02462    Q8CZM4         two hybrid pooling approach  20711500
# 7861    P0C0L4    Q7CJV3         two hybrid pooling approach  20711500
# 7862    Q8ZD36    P02462         two hybrid pooling approach  20711500
# 7863    Q74YC7    P08572         two hybrid pooling approach  20711500
# 7864    P02462    Q7CFR7         two hybrid pooling approach  20711500
# 7865    Q7CK47    P02462         two hybrid pooling approach  20711500
# 7866    Q96FW1    Q9RI12      anti tag coimmunoprecipitation  16364312
# 7867    Q9RI12    Q96FW1                protein kinase assay  16364312
# 7868    Q96FW1    Q9RI12  affinity chromatography technology  16364312
#
#      taxid_a taxid_b                  int_type source_db conf_score
# 0       9606     632      physical association    IntAct       0.37
# 1       9606     632      physical association    IntAct       0.37
# 2       9606     632      physical association    IntAct       0.37
# 3       9606     632      physical association    IntAct       0.37
# 4       9606     632      physical association    IntAct       0.37
# 5       9606     632      physical association    IntAct       0.37
# 6       9606     632      physical association    IntAct       0.37
# 7       9606     632      physical association    IntAct       0.37
# 8       9606     632      physical association    IntAct       0.37
# 9       9606     632      physical association    IntAct       0.37
# 10      9606     632      physical association    IntAct       0.37
# 11      9606     632      physical association    IntAct       0.37
# 12      9606     632      physical association    IntAct       0.37
# 13      9606     632      physical association    IntAct       0.37
# 14      9606     632      physical association    IntAct       0.37
# 15      9606     632      physical association    IntAct       0.37
# 16      9606     632      physical association    IntAct       0.37
# 17      9606     632      physical association    IntAct       0.37
# 18      9606     632      physical association    IntAct       0.37
# 19      9606     632      physical association    IntAct       0.37
# 20      9606     632      physical association    IntAct       0.37
# 21      9606     632      physical association    IntAct       0.37
# 22      9606     632      physical association    IntAct       0.37
# 23      9606     632      physical association    IntAct       0.37
# 24      9606     632      physical association    IntAct       0.37
# 25      9606     632      physical association    IntAct       0.37
# 26      9606     632      physical association    IntAct       0.37
# 27      9606     632      physical association    IntAct       0.37
# 28      9606     632      physical association    IntAct       0.37
# 29      9606     632      physical association    IntAct       0.37
# ...      ...     ...                       ...       ...        ...
# 7839    9606     632      physical association    IntAct       0.37
# 7840    9606     632      physical association    IntAct       0.37
# 7841    9606     632      physical association    IntAct       0.37
# 7842    9606     632      physical association    IntAct       0.37
# 7843     632    9606      physical association    IntAct       0.37
# 7844     632    9606      physical association    IntAct       0.37
# 7845    9606     632      physical association    IntAct       0.37
# 7846     632    9606      physical association    IntAct       0.37
# 7847     632    9606      physical association    IntAct       0.37
# 7848     632    9606      physical association    IntAct       0.37
# 7849    9606     632      physical association    IntAct       0.37
# 7850    9606     632      physical association    IntAct       0.37
# 7851    9606     632      physical association    IntAct       0.37
# 7852    9606     632      physical association    IntAct       0.37
# 7853     632    9606      physical association    IntAct       0.37
# 7854    9606     632      physical association    IntAct       0.37
# 7855    9606     632      physical association    IntAct       0.37
# 7856    9606     632      physical association    IntAct       0.37
# 7857    9606     632      physical association    IntAct       0.37
# 7858     632    9606      physical association    IntAct       0.37
# 7859     632    9606      physical association    IntAct       0.37
# 7860    9606     632      physical association    IntAct       0.37
# 7861    9606     632      physical association    IntAct       0.37
# 7862     632    9606      physical association    IntAct       0.37
# 7863     632    9606      physical association    IntAct       0.37
# 7864    9606     632      physical association    IntAct       0.37
# 7865     632    9606      physical association    IntAct       0.37
# 7866    9606     632      physical association      MINT       0.60
# 7867     632    9606  phosphorylation reaction      MINT       0.60
# 7868    9606     632      physical association      MINT       0.60
#
# [7869 rows x 9 columns]

# %% [markdown]
# Sort columns so pathogen is 'A' and human is 'B'

# %%
df.taxid_a= df.taxid_a.apply(lambda x: str(x))
df.taxid_b = df.taxid_b.apply(lambda x: str(x))
for i in range(len(df)):
    if df.loc[i,"taxid_b"] != '9606':
        A = df.loc[i,"taxid_a"]
        B = df.loc[i,"taxid_b"]
        C = df.loc[i,"protein_a"]
        D = df.loc[i,"protein_b"]
      

        df.loc[i,"taxid_a"] = B
        df.loc[i,"taxid_b"] = A
        df.loc[i,"protein_a"]= D
        df.loc[i,"protein_b"]= C

# %% [markdown]
# Filter out non-HPIs

# %%
sel = df.taxid_b == '9606'

# %%
df = df.loc[sel,:]
print(len(df))

# %%
df

# %%
ID_all =[]
for i in range (0,len(df)):
    ID_list=[]
    ID_list.append (df.iloc[i,0])
    ID_list.append (df.iloc[i,1])
    ID_list.append (df.iloc[i,3])
    ID_list.append (df.iloc[i,2])
    ID_list.sort()
    ID_all.append(
        ID_list[0]
        +ID_list[1] 
        + str(ID_list[2])
        +ID_list[3]
    )
df=df.loc[:,'id']=ID_all
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-74e3ee2827a9> in <module>()
#      13         +ID_list[3]
#      14     )
# ---> 15 df=df.loc[:,'id']=ID_all
#
# AttributeError: 'list' object has no attribute 'loc'

# %%
df
# Out:
#      protein_a protein_b                            d_method  pubmedid  \
# 0       Q7CFX2    Q9UBN7         two hybrid pooling approach  20711500
# 1       Q8ZCT2    Q8WUM4         two hybrid pooling approach  20711500
# 2       Q8ZG09    Q8WUM4         two hybrid pooling approach  20711500
# 3       Q7ARD3    Q8WUM4         two hybrid pooling approach  20711500
# 4       Q7CFP8    Q9NTJ3         two hybrid pooling approach  20711500
# 5       Q56991    Q9NTJ3         two hybrid pooling approach  20711500
# 6       Q9Z381    P42704         two hybrid pooling approach  20711500
# 7       Q8ZIL4    P51572         two hybrid pooling approach  20711500
# 8       Q7CJB1    Q86V81         two hybrid pooling approach  20711500
# 9       Q8ZGJ1    Q99550         two hybrid pooling approach  20711500
# 10      Q7CJU3    P50613         two hybrid pooling approach  20711500
# 11      Q8D068    O43390         two hybrid pooling approach  20711500
# 12      Q7CJF5    O43390         two hybrid pooling approach  20711500
# 13      Q7CGN8    Q13137         two hybrid pooling approach  20711500
# 14      Q8D015    O75886         two hybrid pooling approach  20711500
# 15      Q8D014    O75886         two hybrid pooling approach  20711500
# 16      Q7CK82    Q9UNE7         two hybrid pooling approach  20711500
# 17      Q7CL48    Q9UNE7         two hybrid pooling approach  20711500
# 18      Q7CGH6    Q9UNE7         two hybrid pooling approach  20711500
# 19      Q7CL91    Q9UNE7         two hybrid pooling approach  20711500
# 20      Q7CL85    Q15459         two hybrid pooling approach  20711500
# 21      Q7CJF5    P55265         two hybrid pooling approach  20711500
# 22      Q8ZEC9    O95197         two hybrid pooling approach  20711500
# 23      Q8ZC49    Q15025         two hybrid pooling approach  20711500
# 24      Q7CHY3    Q15025         two hybrid pooling approach  20711500
# 25      Q9Z375    Q13422         two hybrid pooling approach  20711500
# 26      Q8ZD36    P04350         two hybrid pooling approach  20711500
# 27      P58492    P04350         two hybrid pooling approach  20711500
# 28      Q8CZY2    P63244         two hybrid pooling approach  20711500
# 29      Q8D1J6    P63244         two hybrid pooling approach  20711500
# ...        ...       ...                                 ...       ...
# 7839    Q8D1R1    Q96MW5         two hybrid pooling approach  20711500
# 7840    Q8CZQ9    P39059         two hybrid pooling approach  20711500
# 7841    Q8ZA88    Q96JB2         two hybrid pooling approach  20711500
# 7842    Q7CG01    Q96JB2         two hybrid pooling approach  20711500
# 7843    Q8D177    Q14746         two hybrid pooling approach  20711500
# 7844    Q7CJX7    P39059         two hybrid pooling approach  20711500
# 7845    Q7CI41    P23528         two hybrid pooling approach  20711500
# 7846    Q7CKJ7    P23528         two hybrid pooling approach  20711500
# 7847    Q8D0R4    P23528         two hybrid pooling approach  20711500
# 7848    Q7CK47    P23528         two hybrid pooling approach  20711500
# 7849    Q8D0X3    P23528         two hybrid pooling approach  20711500
# 7850    Q7ARB3    Q99715         two hybrid pooling approach  20711500
# 7851    Q7CGU7    P23528         two hybrid pooling approach  20711500
# 7852    Q7CHX9    P23528         two hybrid pooling approach  20711500
# 7853    P58582    P23528         two hybrid pooling approach  20711500
# 7854    Q8CZR4    Q99715         two hybrid pooling approach  20711500
# 7855    Q8ZAR3    P0C0L5         two hybrid pooling approach  20711500
# 7856    Q9ZGX5    P12109         two hybrid pooling approach  20711500
# 7857    Q0WJP9    P12111         two hybrid pooling approach  20711500
# 7858    Q8ZJ73    P12109         two hybrid pooling approach  20711500
# 7859    Q7ARD3    P10643         two hybrid pooling approach  20711500
# 7860    Q8CZM4    P02462         two hybrid pooling approach  20711500
# 7861    Q7CJV3    P0C0L4         two hybrid pooling approach  20711500
# 7862    Q8ZD36    P02462         two hybrid pooling approach  20711500
# 7863    Q74YC7    P08572         two hybrid pooling approach  20711500
# 7864    Q7CFR7    P02462         two hybrid pooling approach  20711500
# 7865    Q7CK47    P02462         two hybrid pooling approach  20711500
# 7866    Q9RI12    Q96FW1      anti tag coimmunoprecipitation  16364312
# 7867    Q9RI12    Q96FW1                protein kinase assay  16364312
# 7868    Q9RI12    Q96FW1  affinity chromatography technology  16364312
#
#      taxid_a taxid_b                  int_type source_db conf_score  \
# 0        632    9606      physical association    IntAct       0.37
# 1        632    9606      physical association    IntAct       0.37
# 2        632    9606      physical association    IntAct       0.37
# 3        632    9606      physical association    IntAct       0.37
# 4        632    9606      physical association    IntAct       0.37
# 5        632    9606      physical association    IntAct       0.37
# 6        632    9606      physical association    IntAct       0.37
# 7        632    9606      physical association    IntAct       0.37
# 8        632    9606      physical association    IntAct       0.37
# 9        632    9606      physical association    IntAct       0.37
# 10       632    9606      physical association    IntAct       0.37
# 11       632    9606      physical association    IntAct       0.37
# 12       632    9606      physical association    IntAct       0.37
# 13       632    9606      physical association    IntAct       0.37
# 14       632    9606      physical association    IntAct       0.37
# 15       632    9606      physical association    IntAct       0.37
# 16       632    9606      physical association    IntAct       0.37
# 17       632    9606      physical association    IntAct       0.37
# 18       632    9606      physical association    IntAct       0.37
# 19       632    9606      physical association    IntAct       0.37
# 20       632    9606      physical association    IntAct       0.37
# 21       632    9606      physical association    IntAct       0.37
# 22       632    9606      physical association    IntAct       0.37
# 23       632    9606      physical association    IntAct       0.37
# 24       632    9606      physical association    IntAct       0.37
# 25       632    9606      physical association    IntAct       0.37
# 26       632    9606      physical association    IntAct       0.37
# 27       632    9606      physical association    IntAct       0.37
# 28       632    9606      physical association    IntAct       0.37
# 29       632    9606      physical association    IntAct       0.37
# ...      ...     ...                       ...       ...        ...
# 7839     632    9606      physical association    IntAct       0.37
# 7840     632    9606      physical association    IntAct       0.37
# 7841     632    9606      physical association    IntAct       0.37
# 7842     632    9606      physical association    IntAct       0.37
# 7843     632    9606      physical association    IntAct       0.37
# 7844     632    9606      physical association    IntAct       0.37
# 7845     632    9606      physical association    IntAct       0.37
# 7846     632    9606      physical association    IntAct       0.37
# 7847     632    9606      physical association    IntAct       0.37
# 7848     632    9606      physical association    IntAct       0.37
# 7849     632    9606      physical association    IntAct       0.37
# 7850     632    9606      physical association    IntAct       0.37
# 7851     632    9606      physical association    IntAct       0.37
# 7852     632    9606      physical association    IntAct       0.37
# 7853     632    9606      physical association    IntAct       0.37
# 7854     632    9606      physical association    IntAct       0.37
# 7855     632    9606      physical association    IntAct       0.37
# 7856     632    9606      physical association    IntAct       0.37
# 7857     632    9606      physical association    IntAct       0.37
# 7858     632    9606      physical association    IntAct       0.37
# 7859     632    9606      physical association    IntAct       0.37
# 7860     632    9606      physical association    IntAct       0.37
# 7861     632    9606      physical association    IntAct       0.37
# 7862     632    9606      physical association    IntAct       0.37
# 7863     632    9606      physical association    IntAct       0.37
# 7864     632    9606      physical association    IntAct       0.37
# 7865     632    9606      physical association    IntAct       0.37
# 7866     632    9606      physical association      MINT       0.60
# 7867     632    9606  phosphorylation reaction      MINT       0.60
# 7868     632    9606      physical association      MINT       0.60
#
#                                                      id
# 0       20711500Q7CFX2Q9UBN7two hybrid pooling approach
# 1       20711500Q8WUM4Q8ZCT2two hybrid pooling approach
# 2       20711500Q8WUM4Q8ZG09two hybrid pooling approach
# 3       20711500Q7ARD3Q8WUM4two hybrid pooling approach
# 4       20711500Q7CFP8Q9NTJ3two hybrid pooling approach
# 5       20711500Q56991Q9NTJ3two hybrid pooling approach
# 6       20711500P42704Q9Z381two hybrid pooling approach
# 7       20711500P51572Q8ZIL4two hybrid pooling approach
# 8       20711500Q7CJB1Q86V81two hybrid pooling approach
# 9       20711500Q8ZGJ1Q99550two hybrid pooling approach
# 10      20711500P50613Q7CJU3two hybrid pooling approach
# 11      20711500O43390Q8D068two hybrid pooling approach
# 12      20711500O43390Q7CJF5two hybrid pooling approach
# 13      20711500Q13137Q7CGN8two hybrid pooling approach
# 14      20711500O75886Q8D015two hybrid pooling approach
# 15      20711500O75886Q8D014two hybrid pooling approach
# 16      20711500Q7CK82Q9UNE7two hybrid pooling approach
# 17      20711500Q7CL48Q9UNE7two hybrid pooling approach
# 18      20711500Q7CGH6Q9UNE7two hybrid pooling approach
# 19      20711500Q7CL91Q9UNE7two hybrid pooling approach
# 20      20711500Q15459Q7CL85two hybrid pooling approach
# 21      20711500P55265Q7CJF5two hybrid pooling approach
# 22      20711500O95197Q8ZEC9two hybrid pooling approach
# 23      20711500Q15025Q8ZC49two hybrid pooling approach
# 24      20711500Q15025Q7CHY3two hybrid pooling approach
# 25      20711500Q13422Q9Z375two hybrid pooling approach
# 26      20711500P04350Q8ZD36two hybrid pooling approach
# 27      20711500P04350P58492two hybrid pooling approach
# 28      20711500P63244Q8CZY2two hybrid pooling approach
# 29      20711500P63244Q8D1J6two hybrid pooling approach
# ...                                                 ...
# 7839    20711500Q8D1R1Q96MW5two hybrid pooling approach
# 7840    20711500P39059Q8CZQ9two hybrid pooling approach
# 7841    20711500Q8ZA88Q96JB2two hybrid pooling approach
# 7842    20711500Q7CG01Q96JB2two hybrid pooling approach
# 7843    20711500Q14746Q8D177two hybrid pooling approach
# 7844    20711500P39059Q7CJX7two hybrid pooling approach
# 7845    20711500P23528Q7CI41two hybrid pooling approach
# 7846    20711500P23528Q7CKJ7two hybrid pooling approach
# 7847    20711500P23528Q8D0R4two hybrid pooling approach
# 7848    20711500P23528Q7CK47two hybrid pooling approach
# 7849    20711500P23528Q8D0X3two hybrid pooling approach
# 7850    20711500Q7ARB3Q99715two hybrid pooling approach
# 7851    20711500P23528Q7CGU7two hybrid pooling approach
# 7852    20711500P23528Q7CHX9two hybrid pooling approach
# 7853    20711500P23528P58582two hybrid pooling approach
# 7854    20711500Q8CZR4Q99715two hybrid pooling approach
# 7855    20711500P0C0L5Q8ZAR3two hybrid pooling approach
# 7856    20711500P12109Q9ZGX5two hybrid pooling approach
# 7857    20711500P12111Q0WJP9two hybrid pooling approach
# 7858    20711500P12109Q8ZJ73two hybrid pooling approach
# 7859    20711500P10643Q7ARD3two hybrid pooling approach
# 7860    20711500P02462Q8CZM4two hybrid pooling approach
# 7861    20711500P0C0L4Q7CJV3two hybrid pooling approach
# 7862    20711500P02462Q8ZD36two hybrid pooling approach
# 7863    20711500P08572Q74YC7two hybrid pooling approach
# 7864    20711500P02462Q7CFR7two hybrid pooling approach
# 7865    20711500P02462Q7CK47two hybrid pooling approach
# 7866  16364312Q96FW1Q9RI12anti tag coimmunoprecipita...
# 7867           16364312Q96FW1Q9RI12protein kinase assay
# 7868  16364312Q96FW1Q9RI12affinity chromatography te...
#
# [7848 rows x 10 columns]

# %%
print(len(df.ID.unique()))
df.pubmedid.unique()
# Out:
# 2275
# array(['20711500'], dtype=object)

# %% [markdown]
# Make identifier PHISTO and make Taxid_B column

# %%
ID_all =[]
for i in range (0,len(PHISTO)):
    ID_list=[]
    ID_list.append (PHISTO.iloc[i,1])
    ID_list.append (PHISTO.iloc[i,2])
    ID_list.append (PHISTO.iloc[i,3])
    ID_list.append (str(PHISTO.iloc[i,4]))
    ID_list.sort()
    ID_all.append(
        ID_list[0]
        +ID_list[1] 
        + ID_list[2]
        + ID_list[3]
    )
PHISTO=PHISTO.assign(ID=ID_all)

PHISTO["taxid_b"]="9606"
PHISTO["source_db"]="PHISTO"

# %%
print(len(PHISTO.ID.unique()))
print(len(PHISTO))
# Out:
# 1331
# 1331

# %% [markdown]
# merge df and PHISTO

# %%
df = pd.concat([df,PHISTO])
len(df)
# Out:
# 3968

# %% [markdown]
# Remove redundancy

# %%
df = df.sort_values(by = "conf_score", ascending = False)
df = df.drop_duplicates("ID")
print(len(df))
# Out:
# 3606

# %% [markdown]
# Count how many times an interaction has been found with different methods, different types of interactions, different publications,...

# %%
count=df.groupby(["source_db"]).count()
count
# Out:
#            Alias_A  Alias_B  Conf_score  D_method    ID  Int_type  Protein_A  \
# Source_DB
# IntAct        2275     2275        2275      2275  2275      2275       2275
# PHISTO           0        0           0      1331  1331         0       1331
#
#            Protein_B  PubmedID  Taxid_A  Taxid_B
# Source_DB
# IntAct          2275      2275     2275     2275
# PHISTO          1331      1331     1331     1331

# %%
df.groupby("pubmedid").size()
# Out:
# PubmedID
# 20711500    1331
# 20711500    2275
# dtype: int64

# %%
df = df.reset_index()
df = df[["taxid_a","taxid_b","protein_a","protein_b","int_type","d_method","pubmedid","source_db","conf_score","ID"]]

# %%
df.to_csv("/Users/thesis/Desktop/Python scripts/Test outputs/" + species, sep ="\t")

# %%
df
# Out:
#      Taxid_A Taxid_B Protein_A   Protein_B              Int_type  \
# 0     119856    9606    Q8G8T7      P13598  physical association
# 1     177416    9606    Q5NID9      Q15650  physical association
# 2     177416    9606    Q5NF74      Q96A61  physical association
# 3     177416    9606    Q5NGC7      Q92547  physical association
# 4     177416    9606    Q5NIP6      O14773  physical association
# 5     177416    9606    Q5NEV2      O94842  physical association
# 6     177416    9606    Q5NES5      Q8IYM9  physical association
# 7     177416    9606    Q5NEX4      Q8NDV7  physical association
# 8     177416    9606    Q5NIP6      Q8NDV7  physical association
# 9     177416    9606    Q5NHD1      O94826  physical association
# 10    177416    9606    Q5NHH2      Q96GC9  physical association
# 11    177416    9606    Q5NEY0      Q06643  physical association
# 12    177416    9606    Q5NF50      Q92956  physical association
# 13    177416    9606    Q5NGT9      Q96BY9  physical association
# 14    177416    9606    Q5NI93      Q15025  physical association
# 15    177416    9606    Q5NH45      Q9HC24  physical association
# 16    177416    9606    Q5NHH2      Q15363  physical association
# 17    177416    9606    Q5NH29      Q9ULS5  physical association
# 18    177416    9606    Q5NIP6      P57088  physical association
# 19    177416    9606    Q5NID2      Q8IYM9  physical association
# 20    177416    9606    Q5NFM0      Q14258  physical association
# 21    177416    9606    Q5NHD1      Q9H5I1  physical association
# 22    177416    9606    Q5NF08      Q8IYM9  physical association
# 23    177416    9606    Q5NGF9      Q6PKC3  physical association
# 24    177416    9606    Q5NHX0      O43396  physical association
# 25    177416    9606    Q5NFP9      Q9BS26  physical association
# 26    177416    9606    Q5NEC0      P63313  physical association
# 27    177416    9606    Q5NHN4      P26651  physical association
# 28    177416    9606    Q5NFN2      O14907  physical association
# 29    177416    9606    Q5NE82      P53804  physical association
# ...      ...     ...       ...         ...                   ...
# 3576  177416    9606    Q5NG97      P30480                   NaN
# 3577  177416    9606    Q5NGF9      Q9BZR9                   NaN
# 3578  177416    9606    Q5NIF9  A0A1L1M261                   NaN
# 3579  177416    9606    Q5NEC0  A0A1L1M261                   NaN
# 3580  177416    9606    Q5NH91  A0A1L1M261                   NaN
# 3581  177416    9606    Q5NGC3  A0A1L1M261                   NaN
# 3582  119856    9606    Q4VP87      Q14590                   NaN
# 3583  119856    9606    Q4VP87      Q96GE9                   NaN
# 3584  119856    9606    Q4VP87      P13693                   NaN
# 3585  119856    9606    Q4VP87      Q8NHL6                   NaN
# 3586  119856    9606    Q4VP87      Q8NHJ6                   NaN
# 3587  119856    9606    Q4VP87      P01877                   NaN
# 3588  119856    9606    Q4VP87      Q86Y74                   NaN
# 3589  119856    9606    Q4VP87      Q86VB7                   NaN
# 3590  119856    9606    Q4VP87      P30480                   NaN
# 3591  119856    9606    Q79RC1      Q10587                   NaN
# 3592  119856    9606    Q79RC1      P31321                   NaN
# 3593  119856    9606    Q79RC1      Q9NZ32                   NaN
# 3594  119856    9606    Q79RC4      Q96GX9                   NaN
# 3595  119856    9606    Q8G8T7      O60763                   NaN
# 3596  119856    9606    Q8G8T7      P19838                   NaN
# 3597  119856    9606    Q8G8T7      Q7Z3K3                   NaN
# 3598  119856    9606    Q8G8T7      P62314                   NaN
# 3599  119856    9606    Q8G8T7      Q9BV68                   NaN
# 3600  119856    9606    Q8G8T7      P01877                   NaN
# 3601  119856    9606    Q8G8T7      P13598                   NaN
# 3602  119856    9606    Q8G8T7      P69905                   NaN
# 3603  119856    9606    Q8G8T7      P52566                   NaN
# 3604  119856    9606    Q8G8T7      Q9Y6C2                   NaN
# 3605  119856    9606    Q8G8T7      D1MGQ2                   NaN
#
#                          D_method  PubmedID Source_DB Conf_score  \
# 0     two hybrid pooling approach  20711500    IntAct       0.37
# 1     two hybrid pooling approach  20711500    IntAct       0.37
# 2     two hybrid pooling approach  20711500    IntAct       0.37
# 3     two hybrid pooling approach  20711500    IntAct       0.37
# 4     two hybrid pooling approach  20711500    IntAct       0.37
# 5     two hybrid pooling approach  20711500    IntAct       0.37
# 6     two hybrid pooling approach  20711500    IntAct       0.37
# 7     two hybrid pooling approach  20711500    IntAct       0.37
# 8     two hybrid pooling approach  20711500    IntAct       0.37
# 9     two hybrid pooling approach  20711500    IntAct       0.37
# 10    two hybrid pooling approach  20711500    IntAct       0.37
# 11    two hybrid pooling approach  20711500    IntAct       0.37
# 12    two hybrid pooling approach  20711500    IntAct       0.37
# 13    two hybrid pooling approach  20711500    IntAct       0.37
# 14    two hybrid pooling approach  20711500    IntAct       0.37
# 15    two hybrid pooling approach  20711500    IntAct       0.37
# 16    two hybrid pooling approach  20711500    IntAct       0.37
# 17    two hybrid pooling approach  20711500    IntAct       0.37
# 18    two hybrid pooling approach  20711500    IntAct       0.37
# 19    two hybrid pooling approach  20711500    IntAct       0.37
# 20    two hybrid pooling approach  20711500    IntAct       0.37
# 21    two hybrid pooling approach  20711500    IntAct       0.37
# 22    two hybrid pooling approach  20711500    IntAct       0.37
# 23    two hybrid pooling approach  20711500    IntAct       0.37
# 24    two hybrid pooling approach  20711500    IntAct       0.37
# 25    two hybrid pooling approach  20711500    IntAct       0.37
# 26    two hybrid pooling approach  20711500    IntAct       0.37
# 27    two hybrid pooling approach  20711500    IntAct       0.37
# 28    two hybrid pooling approach  20711500    IntAct       0.37
# 29    two hybrid pooling approach  20711500    IntAct       0.37
# ...                           ...       ...       ...        ...
# 3576  two hybrid pooling approach  20711500    PHISTO        NaN
# 3577  two hybrid pooling approach  20711500    PHISTO        NaN
# 3578  two hybrid pooling approach  20711500    PHISTO        NaN
# 3579  two hybrid pooling approach  20711500    PHISTO        NaN
# 3580  two hybrid pooling approach  20711500    PHISTO        NaN
# 3581  two hybrid pooling approach  20711500    PHISTO        NaN
# 3582  two hybrid pooling approach  20711500    PHISTO        NaN
# 3583  two hybrid pooling approach  20711500    PHISTO        NaN
# 3584  two hybrid pooling approach  20711500    PHISTO        NaN
# 3585  two hybrid pooling approach  20711500    PHISTO        NaN
# 3586  two hybrid pooling approach  20711500    PHISTO        NaN
# 3587  two hybrid pooling approach  20711500    PHISTO        NaN
# 3588  two hybrid pooling approach  20711500    PHISTO        NaN
# 3589  two hybrid pooling approach  20711500    PHISTO        NaN
# 3590  two hybrid pooling approach  20711500    PHISTO        NaN
# 3591  two hybrid pooling approach  20711500    PHISTO        NaN
# 3592  two hybrid pooling approach  20711500    PHISTO        NaN
# 3593  two hybrid pooling approach  20711500    PHISTO        NaN
# 3594  two hybrid pooling approach  20711500    PHISTO        NaN
# 3595  two hybrid pooling approach  20711500    PHISTO        NaN
# 3596  two hybrid pooling approach  20711500    PHISTO        NaN
# 3597  two hybrid pooling approach  20711500    PHISTO        NaN
# 3598  two hybrid pooling approach  20711500    PHISTO        NaN
# 3599  two hybrid pooling approach  20711500    PHISTO        NaN
# 3600  two hybrid pooling approach  20711500    PHISTO        NaN
# 3601  two hybrid pooling approach  20711500    PHISTO        NaN
# 3602  two hybrid pooling approach  20711500    PHISTO        NaN
# 3603  two hybrid pooling approach  20711500    PHISTO        NaN
# 3604  two hybrid pooling approach  20711500    PHISTO        NaN
# 3605  two hybrid pooling approach  20711500    PHISTO        NaN
#
#                                                      ID
# 0     P13598Q8G8T7psi-mi:icam2_human(display_long)|u...
# 1     Q15650Q5NID9psi-mi:eftu_fratt(display_long)|un...
# 2     Q5NF74Q96A61psi-mi:q5nf74_fratt(display_long)|...
# 3     Q5NGC7Q92547psi-mi:q5ngc7_fratt(display_long)|...
# 4     O14773Q5NIP6psi-mi:gata_fratt(display_long)|un...
# 5     O94842Q5NEV2psi-mi:q5nev2_fratt(display_long)|...
# 6     Q5NES5Q8IYM9psi-mi:q5nes5_fratt(display_long)|...
# 7     Q5NEX4Q8NDV7psi-mi:q5nex4_fratt(display_long)|...
# 8     Q5NIP6Q8NDV7psi-mi:gata_fratt(display_long)|un...
# 9     O94826Q5NHD1psi-mi:q5nhd1_fratt(display_long)|...
# 10    Q5NHH2Q96GC9psi-mi:q5nhh2_fratt(display_long)|...
# 11    Q06643Q5NEY0psi-mi:q5ney0_fratt(display_long)|...
# 12    Q5NF50Q92956psi-mi:q5nf50_fratt(display_long)|...
# 13    Q5NGT9Q96BY9psi-mi:q5ngt9_fratt(display_long)|...
# 14    Q15025Q5NI93psi-mi:q5ni93_fratt(display_long)|...
# 15    Q5NH45Q9HC24psi-mi:lfg4_human(display_long)|un...
# 16    Q15363Q5NHH2psi-mi:q5nhh2_fratt(display_long)|...
# 17    Q5NH29Q9ULS5psi-mi:q5nh29_fratt(display_long)|...
# 18    P57088Q5NIP6psi-mi:gata_fratt(display_long)|un...
# 19    Q5NID2Q8IYM9psi-mi:rpob_fratt(display_long)|un...
# 20    Q14258Q5NFM0psi-mi:q5nfm0_fratt(display_long)|...
# 21    Q5NHD1Q9H5I1psi-mi:q5nhd1_fratt(display_long)|...
# 22    Q5NF08Q8IYM9psi-mi:q5nf08_fratt(display_long)|...
# 23    Q5NGF9Q6PKC3psi-mi:q5ngf9_fratt(display_long)|...
# 24    O43396Q5NHX0psi-mi:efg_fratt(display_long)|uni...
# 25    Q5NFP9Q9BS26psi-mi:erp44_human(display_long)|u...
# 26    P63313Q5NEC0psi-mi:q5nec0_fratt(display_long)|...
# 27    P26651Q5NHN4psi-mi:glgb_fratt(display_long)|un...
# 28    O14907Q5NFN2psi-mi:q5nfn2_fratt(display_long)|...
# 29    P53804Q5NE82psi-mi:q5ne82_fratt(display_long)|...
# ...                                                 ...
# 3576    20711500P30480Q5NG97two hybrid pooling approach
# 3577    20711500Q5NGF9Q9BZR9two hybrid pooling approach
# 3578  20711500A0A1L1M261Q5NIF9two hybrid pooling app...
# 3579  20711500A0A1L1M261Q5NEC0two hybrid pooling app...
# 3580  20711500A0A1L1M261Q5NH91two hybrid pooling app...
# 3581  20711500A0A1L1M261Q5NGC3two hybrid pooling app...
# 3582    20711500Q14590Q4VP87two hybrid pooling approach
# 3583    20711500Q4VP87Q96GE9two hybrid pooling approach
# 3584    20711500P13693Q4VP87two hybrid pooling approach
# 3585    20711500Q4VP87Q8NHL6two hybrid pooling approach
# 3586    20711500Q4VP87Q8NHJ6two hybrid pooling approach
# 3587    20711500P01877Q4VP87two hybrid pooling approach
# 3588    20711500Q4VP87Q86Y74two hybrid pooling approach
# 3589    20711500Q4VP87Q86VB7two hybrid pooling approach
# 3590    20711500P30480Q4VP87two hybrid pooling approach
# 3591    20711500Q10587Q79RC1two hybrid pooling approach
# 3592    20711500P31321Q79RC1two hybrid pooling approach
# 3593    20711500Q79RC1Q9NZ32two hybrid pooling approach
# 3594    20711500Q79RC4Q96GX9two hybrid pooling approach
# 3595    20711500O60763Q8G8T7two hybrid pooling approach
# 3596    20711500P19838Q8G8T7two hybrid pooling approach
# 3597    20711500Q7Z3K3Q8G8T7two hybrid pooling approach
# 3598    20711500P62314Q8G8T7two hybrid pooling approach
# 3599    20711500Q8G8T7Q9BV68two hybrid pooling approach
# 3600    20711500P01877Q8G8T7two hybrid pooling approach
# 3601    20711500P13598Q8G8T7two hybrid pooling approach
# 3602    20711500P69905Q8G8T7two hybrid pooling approach
# 3603    20711500P52566Q8G8T7two hybrid pooling approach
# 3604    20711500Q8G8T7Q9Y6C2two hybrid pooling approach
# 3605    20711500D1MGQ2Q8G8T7two hybrid pooling approach
#
# [3606 rows x 10 columns]
